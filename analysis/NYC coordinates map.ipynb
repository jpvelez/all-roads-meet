# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
intersections = pd.read_csv('../data/nyc_intersections.tsv')

# %%
intersections.describe()
# Out:
#               osmid             lat             lon
# count  8.561823e+06  8561823.000000  8561823.000000
# mean   2.299508e+09      -73.941838       40.724925
# std    9.379539e+08        0.205312        0.135262
# min    2.676978e+07      -74.500999       40.345000
# 25%    2.526696e+09      -74.035613       40.635073
# 50%    2.563746e+09      -73.919914       40.707132
# 75%    2.857976e+09      -73.816564       40.790311
# max    3.822018e+09      -73.226001       41.097000

# %%
# Map all NYC coordinate points - not just for road ways, but all features.
fig = plt.figure(figsize=(30,30))
ax = fig.add_subplot(1,1,1)
ax.scatter(intersections.lat, intersections.lon, marker='.', color='k', alpha=0.01, edgecolor=None)
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
